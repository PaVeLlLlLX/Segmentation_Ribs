# %%
# %%shell
# pip install -q cython
# pip install -qU 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
#
# pip install gdown
# gdown --id 1HGnvRZW-HWkyh7x1_ZlvSAPDcx1OGlNh
# gdown --id 1_HrcPnL5HnmG3m6XvQRK2IYAHf5a5mS_
# unzip few_data_split.zip
#
# git clone https://github.com/comptech-winter-school/coal-composition-control -b dev
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for pycocotools (setup.py) ... done
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1HGnvRZW-HWkyh7x1_ZlvSAPDcx1OGlNh
#
# but Gdown can't. Please check connections and permissions.
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1_HrcPnL5HnmG3m6XvQRK2IYAHf5a5mS_
# To: /content/example.png
# 100% 1.16M/1.16M [00:00<00:00, 115MB/s]
# unzip:  cannot find or open few_data_split.zip, few_data_split.zip.zip or few_data_split.zip.ZIP.
# Cloning into 'coal-composition-control'...
# remote: Enumerating objects: 1806, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 1806 (delta 95), reused 91 (delta 91), pack-reused 1699
# Receiving objects: 100% (1806/1806), 31.92 MiB | 19.96 MiB/s, done.
# Resolving deltas: 100% (1025/1025), done.

# %%
from packaging import version
import numpy as np

#В старом numpy был float, сейчас это float64
if version.parse(np.__version__) >= version.parse("1.24.0"):
  np.float = np.float64

# %%
# %cd coal-composition-control
# !pip install -qU numpy
# !pip install -r requirements.txt
# Out:
# /content/coal-composition-control
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 46.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ERROR: Could not find a version that satisfies the requirement torchvision~=0.11.1 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0)
# ERROR: No matching distribution found for torchvision~=0.11.1

# %%
import torch
from PIL import Image
from pathlib import Path
from train.instance_segmentation.mask_rcnn_dataset import CoalFractionDataset
import os
import random

# %%
'''
def seed_everything(SEED=411, seed_all=False) -> None:
    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)
    torch.cuda.manual_seed(SEED)
    torch.backends.cudnn.deterministic = True
    os.environ['PYTHONHASHSEED']=str(SEED)
    if seed_all:
        torch.cuda.manual_seed_all(SEED)
        torch.backends.cudnn.benchmark = False
'''

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor


def get_instance_segmentation_model(num_classes):
    #pretrained на COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn_v2(pretrained=True)

    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
# %%shell
#
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.11.0
#
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 467608, done.
# remote: Counting objects: 100% (48066/48066), done.
# remote: Compressing objects: 100% (2181/2181), done.
# remote: Total 467608 (delta 45878), reused 47934 (delta 45813), pack-reused 419542
# Receiving objects: 100% (467608/467608), 917.34 MiB | 6.73 MiB/s, done.
# Resolving deltas: 100% (434981/434981), done.
# Note: switching to 'v0.11.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 58a60b2eb4 Fixing bug on SSD backbone freezing. (#4591)

# %%
from engine import train_one_epoch, evaluate
import utils
import transforms as T


def get_transform(train):
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    if train:
        # during training, randomly flip the training images
        # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(p=0.2))
        transforms.append(T.RandomPhotometricDistort(p=0.1))

    return T.Compose(transforms)

# %%
model = torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(pretrained=True)
'''
dataset = CoalFractionDataset(
    root='/content/drive/MyDrive/dataset',
    vgg_json='/content/drive/MyDrive/train_json.json',
    width=2000,
    height=1500,
    transforms=get_transform(train=True)
    )
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=2, shuffle=True, num_workers=2,
    collate_fn=utils.collate_fn
)
# For Training
images, targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images, targets)   # Returns losses and detections
# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)           # Returns predictions
'''
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_V2_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:01<00:00, 150MB/s]
# "\ndataset = CoalFractionDataset(\n    root='/content/drive/MyDrive/dataset',\n    vgg_json='/content/drive/MyDrive/train_json.json',\n    width=2000,\n    height=1500,\n    transforms=get_transform(train=True)\n    )\ndata_loader = torch.utils.data.DataLoader(\n    dataset, batch_size=2, shuffle=True, num_workers=2,\n    collate_fn=utils.collate_fn\n)\n# For Training\nimages, targets = next(iter(data_loader))\nimages = list(image for image in images)\ntargets = [{k: v for k, v in t.items()} for t in targets]\noutput = model(images, targets)   # Returns losses and detections\n# For inference\nmodel.eval()\nx = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]\npredictions = model(x)           # Returns predictions\n"

# %%
# use our dataset and defined transformations
dataset = CoalFractionDataset(
    root='/content/drive/MyDrive/dataset',
    vgg_json='/content/drive/MyDrive/via_project_8Feb2024_19h44m_json.json',
    width=500,
    height=500,
    transforms=get_transform(train=True)
    )
dataset_test = CoalFractionDataset(
    root='/content/drive/MyDrive/dataset_test',
    vgg_json='/content/drive/MyDrive/testRibsSegmented_json.json',
    width=500,
    height=500,
    transforms=get_transform(train=False)
    )


# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=1, shuffle=True, num_workers=1,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=1,
    collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


num_classes = 19

# get the model using our helper function
model = get_instance_segmentation_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
import shutil
fol_path = '/content/drive/MyDrive/dataset/.ipynb_checkpoints'
if os.path.exists(fol_path):
  shutil.rmtree(fol_path)

fold_path = '/content/drive/MyDrive/dataset_test/.ipynb_checkpoints'
if os.path.exists(fold_path):
  shutil.rmtree(fold_path)

# %%
from torch.optim.lr_scheduler import StepLR
num_epochs = 15

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=1)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/15]  eta: 0:00:08  lr: 0.000362  loss: 6.5141 (6.5141)  loss_classifier: 3.3119 (3.3119)  loss_box_reg: 0.4940 (0.4940)  loss_mask: 0.7612 (0.7612)  loss_objectness: 1.8236 (1.8236)  loss_rpn_box_reg: 0.1234 (0.1234)  time: 0.5728  data: 0.1238  max mem: 2934
# Epoch: [0]  [ 1/15]  eta: 0:00:06  lr: 0.000719  loss: 5.8027 (6.1584)  loss_classifier: 3.2789 (3.2954)  loss_box_reg: 0.4430 (0.4685)  loss_mask: 0.7530 (0.7571)  loss_objectness: 1.2514 (1.5375)  loss_rpn_box_reg: 0.0764 (0.0999)  time: 0.4797  data: 0.0650  max mem: 3030
# Epoch: [0]  [ 2/15]  eta: 0:00:05  lr: 0.001075  loss: 5.9988 (6.1052)  loss_classifier: 3.2789 (3.2704)  loss_box_reg: 0.4940 (0.5234)  loss_mask: 0.7612 (0.7601)  loss_objectness: 1.2802 (1.4518)  loss_rpn_box_reg: 0.0989 (0.0996)  time: 0.4468  data: 0.0452  max mem: 3157
# Epoch: [0]  [ 3/15]  eta: 0:00:05  lr: 0.001432  loss: 5.8027 (5.8999)  loss_classifier: 3.2204 (3.2102)  loss_box_reg: 0.4940 (0.5511)  loss_mask: 0.7612 (0.7658)  loss_objectness: 1.2514 (1.2689)  loss_rpn_box_reg: 0.0989 (0.1039)  time: 0.4397  data: 0.0364  max mem: 3206
# Epoch: [0]  [ 4/15]  eta: 0:00:04  lr: 0.001789  loss: 5.8027 (5.6715)  loss_classifier: 3.2204 (3.1084)  loss_box_reg: 0.6332 (0.6226)  loss_mask: 0.7612 (0.7588)  loss_objectness: 1.2514 (1.0805)  loss_rpn_box_reg: 0.0989 (0.1011)  time: 0.4330  data: 0.0313  max mem: 3256
# Epoch: [0]  [ 5/15]  eta: 0:00:04  lr: 0.002146  loss: 5.2840 (5.4124)  loss_classifier: 3.0295 (2.9652)  loss_box_reg: 0.6332 (0.6659)  loss_mask: 0.7530 (0.7498)  loss_objectness: 0.7205 (0.9339)  loss_rpn_box_reg: 0.0900 (0.0977)  time: 0.4260  data: 0.0273  max mem: 3256
# Epoch: [0]  [ 6/15]  eta: 0:00:03  lr: 0.002503  loss: 5.2840 (5.1719)  loss_classifier: 3.0295 (2.7908)  loss_box_reg: 0.6340 (0.7128)  loss_mask: 0.7530 (0.7339)  loss_objectness: 0.7205 (0.8398)  loss_rpn_box_reg: 0.0900 (0.0945)  time: 0.4181  data: 0.0244  max mem: 3256
# Epoch: [0]  [ 7/15]  eta: 0:00:03  lr: 0.002859  loss: 4.7576 (4.8969)  loss_classifier: 2.7012 (2.5987)  loss_box_reg: 0.6340 (0.7407)  loss_mask: 0.7307 (0.7185)  loss_objectness: 0.3269 (0.7458)  loss_rpn_box_reg: 0.0844 (0.0933)  time: 0.4147  data: 0.0222  max mem: 3256
# Epoch: [0]  [ 8/15]  eta: 0:00:02  lr: 0.003216  loss: 4.7576 (4.6384)  loss_classifier: 2.7012 (2.4181)  loss_box_reg: 0.8699 (0.7551)  loss_mask: 0.7307 (0.7039)  loss_objectness: 0.3269 (0.6676)  loss_rpn_box_reg: 0.0900 (0.0937)  time: 0.4116  data: 0.0205  max mem: 3257
# Epoch: [0]  [ 9/15]  eta: 0:00:02  lr: 0.003573  loss: 4.1170 (4.4160)  loss_classifier: 2.2491 (2.2613)  loss_box_reg: 0.8699 (0.7677)  loss_mask: 0.7047 (0.6903)  loss_objectness: 0.2756 (0.6066)  loss_rpn_box_reg: 0.0844 (0.0901)  time: 0.4127  data: 0.0191  max mem: 3297
# Epoch: [0]  [10/15]  eta: 0:00:02  lr: 0.003930  loss: 4.1170 (4.2604)  loss_classifier: 2.2491 (2.1393)  loss_box_reg: 0.8699 (0.7742)  loss_mask: 0.7047 (0.6806)  loss_objectness: 0.2756 (0.5758)  loss_rpn_box_reg: 0.0900 (0.0904)  time: 0.4106  data: 0.0180  max mem: 3297
# Epoch: [0]  [11/15]  eta: 0:00:01  lr: 0.004286  loss: 3.7287 (4.1125)  loss_classifier: 1.7447 (2.0337)  loss_box_reg: 0.8699 (0.7928)  loss_mask: 0.6386 (0.6626)  loss_objectness: 0.2686 (0.5348)  loss_rpn_box_reg: 0.0844 (0.0886)  time: 0.4088  data: 0.0171  max mem: 3297
# Epoch: [0]  [12/15]  eta: 0:00:01  lr: 0.004643  loss: 3.7287 (3.9665)  loss_classifier: 1.7447 (1.9315)  loss_box_reg: 0.8816 (0.8005)  loss_mask: 0.6386 (0.6453)  loss_objectness: 0.2686 (0.5002)  loss_rpn_box_reg: 0.0900 (0.0891)  time: 0.4075  data: 0.0162  max mem: 3297
# Epoch: [0]  [13/15]  eta: 0:00:00  lr: 0.005000  loss: 2.9722 (3.8386)  loss_classifier: 1.2540 (1.8426)  loss_box_reg: 0.8732 (0.8057)  loss_mask: 0.6107 (0.6322)  loss_objectness: 0.2004 (0.4683)  loss_rpn_box_reg: 0.0900 (0.0898)  time: 0.4062  data: 0.0155  max mem: 3297
# Epoch: [0]  [14/15]  eta: 0:00:00  lr: 0.005000  loss: 2.9722 (3.7167)  loss_classifier: 1.2540 (1.7495)  loss_box_reg: 0.8732 (0.8069)  loss_mask: 0.6107 (0.6188)  loss_objectness: 0.2641 (0.4547)  loss_rpn_box_reg: 0.0900 (0.0868)  time: 0.4054  data: 0.0149  max mem: 3297
# Epoch: [0] Total time: 0:00:06 (0.4088 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:02  model_time: 0.3383 (0.3383)  evaluator_time: 0.1311 (0.1311)  time: 0.5677  data: 0.0964  max mem: 3297
# Test:  [4/5]  eta: 0:00:00  model_time: 0.2497 (0.2644)  evaluator_time: 0.1292 (0.1231)  time: 0.4176  data: 0.0235  max mem: 3297
# Test: Total time: 0:00:02 (0.4242 s / it)
# Averaged stats: model_time: 0.2497 (0.2644)  evaluator_time: 0.1292 (0.1231)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.214
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.428
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [1]  [ 0/15]  eta: 0:00:07  lr: 0.005000  loss: 1.9284 (1.9284)  loss_classifier: 0.3674 (0.3674)  loss_box_reg: 0.7940 (0.7940)  loss_mask: 0.5883 (0.5883)  loss_objectness: 0.0860 (0.0860)  loss_rpn_box_reg: 0.0927 (0.0927)  time: 0.4900  data: 0.1025  max mem: 3297
# Epoch: [1]  [ 1/15]  eta: 0:00:06  lr: 0.005000  loss: 1.6773 (1.8029)  loss_classifier: 0.2598 (0.3136)  loss_box_reg: 0.7783 (0.7862)  loss_mask: 0.4175 (0.5029)  loss_objectness: 0.0860 (0.1129)  loss_rpn_box_reg: 0.0818 (0.0873)  time: 0.4303  data: 0.0552  max mem: 3297
# Epoch: [1]  [ 2/15]  eta: 0:00:05  lr: 0.005000  loss: 1.6773 (1.7393)  loss_classifier: 0.3089 (0.3120)  loss_box_reg: 0.7783 (0.7674)  loss_mask: 0.4201 (0.4753)  loss_objectness: 0.1151 (0.1136)  loss_rpn_box_reg: 0.0818 (0.0710)  time: 0.4193  data: 0.0396  max mem: 3297
# Epoch: [1]  [ 3/15]  eta: 0:00:04  lr: 0.005000  loss: 1.6773 (1.7553)  loss_classifier: 0.3089 (0.3334)  loss_box_reg: 0.7298 (0.7574)  loss_mask: 0.4201 (0.4707)  loss_objectness: 0.0953 (0.1090)  loss_rpn_box_reg: 0.0818 (0.0847)  time: 0.4121  data: 0.0313  max mem: 3297
# Epoch: [1]  [ 4/15]  eta: 0:00:04  lr: 0.005000  loss: 1.6773 (1.7338)  loss_classifier: 0.3089 (0.3268)  loss_box_reg: 0.7298 (0.7475)  loss_mask: 0.4545 (0.4675)  loss_objectness: 0.1151 (0.1149)  loss_rpn_box_reg: 0.0818 (0.0771)  time: 0.4086  data: 0.0263  max mem: 3297
# Epoch: [1]  [ 5/15]  eta: 0:00:04  lr: 0.005000  loss: 1.6476 (1.6947)  loss_classifier: 0.3089 (0.3301)  loss_box_reg: 0.7275 (0.7413)  loss_mask: 0.4201 (0.4504)  loss_objectness: 0.0953 (0.1009)  loss_rpn_box_reg: 0.0465 (0.0719)  time: 0.4066  data: 0.0233  max mem: 3297
# Epoch: [1]  [ 6/15]  eta: 0:00:03  lr: 0.005000  loss: 1.6476 (1.6846)  loss_classifier: 0.3089 (0.3248)  loss_box_reg: 0.7275 (0.7388)  loss_mask: 0.4545 (0.4550)  loss_objectness: 0.0953 (0.0964)  loss_rpn_box_reg: 0.0562 (0.0697)  time: 0.4051  data: 0.0209  max mem: 3297
# Epoch: [1]  [ 7/15]  eta: 0:00:03  lr: 0.005000  loss: 1.6240 (1.6601)  loss_classifier: 0.3005 (0.3166)  loss_box_reg: 0.7275 (0.7385)  loss_mask: 0.4201 (0.4475)  loss_objectness: 0.0860 (0.0896)  loss_rpn_box_reg: 0.0551 (0.0679)  time: 0.4038  data: 0.0191  max mem: 3297
# Epoch: [1]  [ 8/15]  eta: 0:00:02  lr: 0.005000  loss: 1.6240 (1.6167)  loss_classifier: 0.3005 (0.3037)  loss_box_reg: 0.7275 (0.7217)  loss_mask: 0.4201 (0.4356)  loss_objectness: 0.0860 (0.0880)  loss_rpn_box_reg: 0.0562 (0.0677)  time: 0.4031  data: 0.0177  max mem: 3297
# Epoch: [1]  [ 9/15]  eta: 0:00:02  lr: 0.005000  loss: 1.6122 (1.6082)  loss_classifier: 0.2930 (0.3018)  loss_box_reg: 0.7234 (0.7194)  loss_mask: 0.4201 (0.4392)  loss_objectness: 0.0758 (0.0819)  loss_rpn_box_reg: 0.0551 (0.0658)  time: 0.4053  data: 0.0166  max mem: 3301
# Epoch: [1]  [10/15]  eta: 0:00:02  lr: 0.005000  loss: 1.6122 (1.5756)  loss_classifier: 0.2930 (0.2909)  loss_box_reg: 0.7234 (0.7096)  loss_mask: 0.4201 (0.4313)  loss_objectness: 0.0758 (0.0771)  loss_rpn_box_reg: 0.0562 (0.0667)  time: 0.4049  data: 0.0158  max mem: 3301
# Epoch: [1]  [11/15]  eta: 0:00:01  lr: 0.005000  loss: 1.5318 (1.5700)  loss_classifier: 0.2847 (0.2878)  loss_box_reg: 0.7106 (0.7053)  loss_mask: 0.4201 (0.4346)  loss_objectness: 0.0689 (0.0752)  loss_rpn_box_reg: 0.0562 (0.0672)  time: 0.4056  data: 0.0151  max mem: 3301
# Epoch: [1]  [12/15]  eta: 0:00:01  lr: 0.005000  loss: 1.5318 (1.5590)  loss_classifier: 0.2847 (0.2870)  loss_box_reg: 0.7234 (0.7069)  loss_mask: 0.4201 (0.4296)  loss_objectness: 0.0689 (0.0707)  loss_rpn_box_reg: 0.0562 (0.0648)  time: 0.4054  data: 0.0144  max mem: 3301
# Epoch: [1]  [13/15]  eta: 0:00:00  lr: 0.005000  loss: 1.5318 (1.5679)  loss_classifier: 0.2847 (0.2987)  loss_box_reg: 0.7106 (0.7065)  loss_mask: 0.4201 (0.4300)  loss_objectness: 0.0546 (0.0666)  loss_rpn_box_reg: 0.0562 (0.0661)  time: 0.4071  data: 0.0138  max mem: 3301
# Epoch: [1]  [14/15]  eta: 0:00:00  lr: 0.005000  loss: 1.5318 (1.5605)  loss_classifier: 0.2930 (0.3016)  loss_box_reg: 0.7106 (0.7029)  loss_mask: 0.4201 (0.4248)  loss_objectness: 0.0546 (0.0649)  loss_rpn_box_reg: 0.0663 (0.0663)  time: 0.4064  data: 0.0134  max mem: 3301
# Epoch: [1] Total time: 0:00:06 (0.4113 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:02  model_time: 0.2582 (0.2582)  evaluator_time: 0.1028 (0.1028)  time: 0.4985  data: 0.1351  max mem: 3301
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1953 (0.1980)  evaluator_time: 0.0636 (0.0713)  time: 0.3062  data: 0.0335  max mem: 3301
# Test: Total time: 0:00:01 (0.3128 s / it)
# Averaged stats: model_time: 0.1953 (0.1980)  evaluator_time: 0.0636 (0.0713)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.612
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.290
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [2]  [ 0/15]  eta: 0:00:07  lr: 0.005000  loss: 1.2014 (1.2014)  loss_classifier: 0.1796 (0.1796)  loss_box_reg: 0.6088 (0.6088)  loss_mask: 0.3350 (0.3350)  loss_objectness: 0.0505 (0.0505)  loss_rpn_box_reg: 0.0275 (0.0275)  time: 0.4966  data: 0.1054  max mem: 3301
# Epoch: [2]  [ 1/15]  eta: 0:00:06  lr: 0.005000  loss: 1.2014 (1.2827)  loss_classifier: 0.1796 (0.2218)  loss_box_reg: 0.6022 (0.6055)  loss_mask: 0.3350 (0.3794)  loss_objectness: 0.0109 (0.0307)  loss_rpn_box_reg: 0.0275 (0.0453)  time: 0.4598  data: 0.0562  max mem: 3301
# Epoch: [2]  [ 2/15]  eta: 0:00:05  lr: 0.005000  loss: 1.3101 (1.2918)  loss_classifier: 0.1796 (0.2067)  loss_box_reg: 0.6088 (0.6404)  loss_mask: 0.3350 (0.3635)  loss_objectness: 0.0185 (0.0266)  loss_rpn_box_reg: 0.0631 (0.0545)  time: 0.4421  data: 0.0397  max mem: 3301
# Epoch: [2]  [ 3/15]  eta: 0:00:05  lr: 0.005000  loss: 1.3101 (1.3351)  loss_classifier: 0.1796 (0.2188)  loss_box_reg: 0.6088 (0.6501)  loss_mask: 0.3350 (0.3875)  loss_objectness: 0.0156 (0.0239)  loss_rpn_box_reg: 0.0560 (0.0549)  time: 0.4303  data: 0.0313  max mem: 3301
# Epoch: [2]  [ 4/15]  eta: 0:00:04  lr: 0.005000  loss: 1.3101 (1.2886)  loss_classifier: 0.2033 (0.2157)  loss_box_reg: 0.6088 (0.6225)  loss_mask: 0.3350 (0.3715)  loss_objectness: 0.0185 (0.0256)  loss_rpn_box_reg: 0.0560 (0.0533)  time: 0.4194  data: 0.0265  max mem: 3301
# Epoch: [2]  [ 5/15]  eta: 0:00:04  lr: 0.005000  loss: 1.2900 (1.2888)  loss_classifier: 0.2033 (0.2223)  loss_box_reg: 0.6025 (0.6191)  loss_mask: 0.3350 (0.3689)  loss_objectness: 0.0185 (0.0261)  loss_rpn_box_reg: 0.0475 (0.0524)  time: 0.4159  data: 0.0232  max mem: 3301
# Epoch: [2]  [ 6/15]  eta: 0:00:03  lr: 0.005000  loss: 1.2900 (1.2807)  loss_classifier: 0.2381 (0.2245)  loss_box_reg: 0.6025 (0.6104)  loss_mask: 0.3523 (0.3665)  loss_objectness: 0.0289 (0.0285)  loss_rpn_box_reg: 0.0475 (0.0507)  time: 0.4136  data: 0.0212  max mem: 3301
# Epoch: [2]  [ 7/15]  eta: 0:00:03  lr: 0.005000  loss: 1.2504 (1.2769)  loss_classifier: 0.2269 (0.2248)  loss_box_reg: 0.6025 (0.6112)  loss_mask: 0.3523 (0.3654)  loss_objectness: 0.0185 (0.0262)  loss_rpn_box_reg: 0.0471 (0.0492)  time: 0.4151  data: 0.0195  max mem: 3301
# Epoch: [2]  [ 8/15]  eta: 0:00:02  lr: 0.005000  loss: 1.2504 (1.2680)  loss_classifier: 0.2361 (0.2261)  loss_box_reg: 0.6025 (0.6069)  loss_mask: 0.3523 (0.3608)  loss_objectness: 0.0185 (0.0251)  loss_rpn_box_reg: 0.0475 (0.0491)  time: 0.4135  data: 0.0180  max mem: 3301
# Epoch: [2]  [ 9/15]  eta: 0:00:02  lr: 0.005000  loss: 1.2319 (1.2589)  loss_classifier: 0.2269 (0.2206)  loss_box_reg: 0.6025 (0.6106)  loss_mask: 0.3350 (0.3561)  loss_objectness: 0.0164 (0.0240)  loss_rpn_box_reg: 0.0471 (0.0477)  time: 0.4132  data: 0.0182  max mem: 3301
# Epoch: [2]  [10/15]  eta: 0:00:02  lr: 0.005000  loss: 1.2319 (1.2542)  loss_classifier: 0.2269 (0.2179)  loss_box_reg: 0.6088 (0.6110)  loss_mask: 0.3350 (0.3535)  loss_objectness: 0.0185 (0.0244)  loss_rpn_box_reg: 0.0471 (0.0474)  time: 0.4118  data: 0.0171  max mem: 3301
# Epoch: [2]  [11/15]  eta: 0:00:01  lr: 0.005000  loss: 1.2080 (1.2345)  loss_classifier: 0.2033 (0.2143)  loss_box_reg: 0.6025 (0.6005)  loss_mask: 0.3318 (0.3497)  loss_objectness: 0.0164 (0.0233)  loss_rpn_box_reg: 0.0449 (0.0468)  time: 0.4107  data: 0.0162  max mem: 3301
# Epoch: [2]  [12/15]  eta: 0:00:01  lr: 0.005000  loss: 1.2080 (1.2203)  loss_classifier: 0.2033 (0.2122)  loss_box_reg: 0.6025 (0.5933)  loss_mask: 0.3318 (0.3469)  loss_objectness: 0.0164 (0.0226)  loss_rpn_box_reg: 0.0449 (0.0452)  time: 0.4100  data: 0.0155  max mem: 3301
# Epoch: [2]  [13/15]  eta: 0:00:00  lr: 0.005000  loss: 1.2080 (1.2196)  loss_classifier: 0.1914 (0.2097)  loss_box_reg: 0.6022 (0.5922)  loss_mask: 0.3318 (0.3514)  loss_objectness: 0.0156 (0.0217)  loss_rpn_box_reg: 0.0411 (0.0445)  time: 0.4094  data: 0.0148  max mem: 3301
# Epoch: [2]  [14/15]  eta: 0:00:00  lr: 0.005000  loss: 1.2111 (1.2229)  loss_classifier: 0.2033 (0.2135)  loss_box_reg: 0.6025 (0.5933)  loss_mask: 0.3318 (0.3482)  loss_objectness: 0.0164 (0.0214)  loss_rpn_box_reg: 0.0449 (0.0465)  time: 0.4086  data: 0.0142  max mem: 3301
# Epoch: [2] Total time: 0:00:06 (0.4119 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:01  model_time: 0.2006 (0.2006)  evaluator_time: 0.0694 (0.0694)  time: 0.3669  data: 0.0951  max mem: 3301
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1893 (0.1853)  evaluator_time: 0.0613 (0.0598)  time: 0.2715  data: 0.0228  max mem: 3301
# Test: Total time: 0:00:01 (0.2774 s / it)
# Averaged stats: model_time: 0.1893 (0.1853)  evaluator_time: 0.0613 (0.0598)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.866
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.269
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.445
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.238
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.079
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.045
# Epoch: [3]  [ 0/15]  eta: 0:00:07  lr: 0.000500  loss: 1.0531 (1.0531)  loss_classifier: 0.1781 (0.1781)  loss_box_reg: 0.5504 (0.5504)  loss_mask: 0.2938 (0.2938)  loss_objectness: 0.0034 (0.0034)  loss_rpn_box_reg: 0.0274 (0.0274)  time: 0.4985  data: 0.0999  max mem: 3301
# Epoch: [3]  [ 1/15]  eta: 0:00:06  lr: 0.000500  loss: 1.0531 (1.0980)  loss_classifier: 0.1496 (0.1638)  loss_box_reg: 0.5504 (0.5890)  loss_mask: 0.2938 (0.2966)  loss_objectness: 0.0034 (0.0144)  loss_rpn_box_reg: 0.0274 (0.0342)  time: 0.4496  data: 0.0552  max mem: 3301
# Epoch: [3]  [ 2/15]  eta: 0:00:05  lr: 0.000500  loss: 1.1101 (1.1020)  loss_classifier: 0.1781 (0.1858)  loss_box_reg: 0.5504 (0.5620)  loss_mask: 0.2938 (0.2951)  loss_objectness: 0.0169 (0.0152)  loss_rpn_box_reg: 0.0409 (0.0440)  time: 0.4347  data: 0.0394  max mem: 3301
# Epoch: [3]  [ 3/15]  eta: 0:00:05  lr: 0.000500  loss: 1.0531 (1.0806)  loss_classifier: 0.1781 (0.1897)  loss_box_reg: 0.5079 (0.5474)  loss_mask: 0.2921 (0.2861)  loss_objectness: 0.0169 (0.0161)  loss_rpn_box_reg: 0.0327 (0.0412)  time: 0.4228  data: 0.0322  max mem: 3301
# Epoch: [3]  [ 4/15]  eta: 0:00:04  lr: 0.000500  loss: 1.0531 (1.0629)  loss_classifier: 0.1781 (0.1852)  loss_box_reg: 0.5079 (0.5386)  loss_mask: 0.2921 (0.2858)  loss_objectness: 0.0169 (0.0157)  loss_rpn_box_reg: 0.0327 (0.0376)  time: 0.4193  data: 0.0271  max mem: 3301
# Epoch: [3]  [ 5/15]  eta: 0:00:04  lr: 0.000500  loss: 1.0352 (1.0583)  loss_classifier: 0.1781 (0.1864)  loss_box_reg: 0.5039 (0.5258)  loss_mask: 0.2921 (0.2877)  loss_objectness: 0.0169 (0.0172)  loss_rpn_box_reg: 0.0327 (0.0412)  time: 0.4215  data: 0.0255  max mem: 3301
# Epoch: [3]  [ 6/15]  eta: 0:00:03  lr: 0.000500  loss: 1.0531 (1.0688)  loss_classifier: 0.1927 (0.1925)  loss_box_reg: 0.5079 (0.5268)  loss_mask: 0.2938 (0.2922)  loss_objectness: 0.0189 (0.0178)  loss_rpn_box_reg: 0.0327 (0.0395)  time: 0.4254  data: 0.0242  max mem: 3301
# Epoch: [3]  [ 7/15]  eta: 0:00:03  lr: 0.000500  loss: 1.0352 (1.0591)  loss_classifier: 0.1781 (0.1892)  loss_box_reg: 0.5039 (0.5191)  loss_mask: 0.2938 (0.2935)  loss_objectness: 0.0189 (0.0196)  loss_rpn_box_reg: 0.0297 (0.0376)  time: 0.4227  data: 0.0220  max mem: 3301
# Epoch: [3]  [ 8/15]  eta: 0:00:02  lr: 0.000500  loss: 1.0531 (1.0702)  loss_classifier: 0.1927 (0.1917)  loss_box_reg: 0.5079 (0.5210)  loss_mask: 0.2972 (0.3019)  loss_objectness: 0.0189 (0.0186)  loss_rpn_box_reg: 0.0327 (0.0370)  time: 0.4222  data: 0.0205  max mem: 3301
# Epoch: [3]  [ 9/15]  eta: 0:00:02  lr: 0.000500  loss: 1.0531 (1.0687)  loss_classifier: 0.1853 (0.1911)  loss_box_reg: 0.5079 (0.5221)  loss_mask: 0.2938 (0.3002)  loss_objectness: 0.0189 (0.0188)  loss_rpn_box_reg: 0.0320 (0.0365)  time: 0.4213  data: 0.0191  max mem: 3301
# Epoch: [3]  [10/15]  eta: 0:00:02  lr: 0.000500  loss: 1.0531 (1.0584)  loss_classifier: 0.1853 (0.1897)  loss_box_reg: 0.5079 (0.5179)  loss_mask: 0.2938 (0.2970)  loss_objectness: 0.0194 (0.0188)  loss_rpn_box_reg: 0.0320 (0.0350)  time: 0.4197  data: 0.0181  max mem: 3301
# Epoch: [3]  [11/15]  eta: 0:00:01  lr: 0.000500  loss: 1.0352 (1.0521)  loss_classifier: 0.1853 (0.1920)  loss_box_reg: 0.5039 (0.5106)  loss_mask: 0.2938 (0.2967)  loss_objectness: 0.0189 (0.0180)  loss_rpn_box_reg: 0.0312 (0.0347)  time: 0.4185  data: 0.0172  max mem: 3301
# Epoch: [3]  [12/15]  eta: 0:00:01  lr: 0.000500  loss: 1.0531 (1.0537)  loss_classifier: 0.1853 (0.1903)  loss_box_reg: 0.5079 (0.5127)  loss_mask: 0.2944 (0.2971)  loss_objectness: 0.0189 (0.0181)  loss_rpn_box_reg: 0.0320 (0.0354)  time: 0.4174  data: 0.0164  max mem: 3301
# Epoch: [3]  [13/15]  eta: 0:00:00  lr: 0.000500  loss: 1.0531 (1.0654)  loss_classifier: 0.1815 (0.1897)  loss_box_reg: 0.5079 (0.5185)  loss_mask: 0.2944 (0.3039)  loss_objectness: 0.0185 (0.0175)  loss_rpn_box_reg: 0.0320 (0.0358)  time: 0.4164  data: 0.0156  max mem: 3301
# Epoch: [3]  [14/15]  eta: 0:00:00  lr: 0.000500  loss: 1.0554 (1.0696)  loss_classifier: 0.1853 (0.1924)  loss_box_reg: 0.5079 (0.5170)  loss_mask: 0.2972 (0.3062)  loss_objectness: 0.0189 (0.0178)  loss_rpn_box_reg: 0.0327 (0.0363)  time: 0.4175  data: 0.0150  max mem: 3301
# Epoch: [3] Total time: 0:00:06 (0.4216 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:01  model_time: 0.1816 (0.1816)  evaluator_time: 0.0575 (0.0575)  time: 0.3376  data: 0.0968  max mem: 3301
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1728 (0.1738)  evaluator_time: 0.0550 (0.0542)  time: 0.2546  data: 0.0233  max mem: 3301
# Test: Total time: 0:00:01 (0.2622 s / it)
# Averaged stats: model_time: 0.1728 (0.1738)  evaluator_time: 0.0550 (0.0542)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.868
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.233
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.542
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.197
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.128
# Epoch: [4]  [ 0/15]  eta: 0:00:07  lr: 0.000500  loss: 1.1184 (1.1184)  loss_classifier: 0.2347 (0.2347)  loss_box_reg: 0.4959 (0.4959)  loss_mask: 0.3321 (0.3321)  loss_objectness: 0.0142 (0.0142)  loss_rpn_box_reg: 0.0415 (0.0415)  time: 0.5285  data: 0.1015  max mem: 3301
# Epoch: [4]  [ 1/15]  eta: 0:00:06  lr: 0.000500  loss: 0.9972 (1.0578)  loss_classifier: 0.1599 (0.1973)  loss_box_reg: 0.4791 (0.4875)  loss_mask: 0.3103 (0.3212)  loss_objectness: 0.0142 (0.0180)  loss_rpn_box_reg: 0.0262 (0.0338)  time: 0.4670  data: 0.0548  max mem: 3301
# Epoch: [4]  [ 2/15]  eta: 0:00:05  lr: 0.000500  loss: 1.1184 (1.0927)  loss_classifier: 0.2143 (0.2030)  loss_box_reg: 0.4959 (0.5039)  loss_mask: 0.3321 (0.3363)  loss_objectness: 0.0159 (0.0173)  loss_rpn_box_reg: 0.0290 (0.0322)  time: 0.4496  data: 0.0390  max mem: 3301
# Epoch: [4]  [ 3/15]  eta: 0:00:05  lr: 0.000500  loss: 1.1184 (1.1011)  loss_classifier: 0.2047 (0.2034)  loss_box_reg: 0.4959 (0.5068)  loss_mask: 0.3308 (0.3349)  loss_objectness: 0.0159 (0.0181)  loss_rpn_box_reg: 0.0290 (0.0378)  time: 0.4391  data: 0.0309  max mem: 3301
# Epoch: [4]  [ 4/15]  eta: 0:00:04  lr: 0.000500  loss: 1.1184 (1.0895)  loss_classifier: 0.2047 (0.1986)  loss_box_reg: 0.5153 (0.5085)  loss_mask: 0.3308 (0.3268)  loss_objectness: 0.0159 (0.0173)  loss_rpn_box_reg: 0.0399 (0.0383)  time: 0.4329  data: 0.0260  max mem: 3301
# Epoch: [4]  [ 5/15]  eta: 0:00:04  lr: 0.000500  loss: 1.0432 (1.0632)  loss_classifier: 0.1814 (0.1957)  loss_box_reg: 0.4959 (0.4998)  loss_mask: 0.3103 (0.3158)  loss_objectness: 0.0142 (0.0159)  loss_rpn_box_reg: 0.0290 (0.0359)  time: 0.4247  data: 0.0228  max mem: 3301
# Epoch: [4]  [ 6/15]  eta: 0:00:03  lr: 0.000500  loss: 1.0697 (1.0642)  loss_classifier: 0.2047 (0.1977)  loss_box_reg: 0.5103 (0.5013)  loss_mask: 0.3103 (0.3105)  loss_objectness: 0.0159 (0.0166)  loss_rpn_box_reg: 0.0399 (0.0380)  time: 0.4219  data: 0.0204  max mem: 3301
# Epoch: [4]  [ 7/15]  eta: 0:00:03  lr: 0.000500  loss: 1.0697 (1.0674)  loss_classifier: 0.1814 (0.1946)  loss_box_reg: 0.5038 (0.5016)  loss_mask: 0.3103 (0.3182)  loss_objectness: 0.0142 (0.0157)  loss_rpn_box_reg: 0.0314 (0.0372)  time: 0.4198  data: 0.0187  max mem: 3301
# Epoch: [4]  [ 8/15]  eta: 0:00:02  lr: 0.000500  loss: 1.0697 (1.0457)  loss_classifier: 0.1814 (0.1902)  loss_box_reg: 0.5038 (0.4900)  loss_mask: 0.3103 (0.3142)  loss_objectness: 0.0159 (0.0160)  loss_rpn_box_reg: 0.0314 (0.0352)  time: 0.4189  data: 0.0174  max mem: 3301
# Epoch: [4]  [ 9/15]  eta: 0:00:02  lr: 0.000500  loss: 1.0432 (1.0396)  loss_classifier: 0.1794 (0.1880)  loss_box_reg: 0.5038 (0.4921)  loss_mask: 0.2946 (0.3103)  loss_objectness: 0.0142 (0.0156)  loss_rpn_box_reg: 0.0290 (0.0335)  time: 0.4179  data: 0.0163  max mem: 3301
# Epoch: [4]  [10/15]  eta: 0:00:02  lr: 0.000500  loss: 1.0432 (1.0311)  loss_classifier: 0.1794 (0.1850)  loss_box_reg: 0.5038 (0.4920)  loss_mask: 0.2946 (0.3055)  loss_objectness: 0.0142 (0.0149)  loss_rpn_box_reg: 0.0314 (0.0337)  time: 0.4178  data: 0.0155  max mem: 3301
# Epoch: [4]  [11/15]  eta: 0:00:01  lr: 0.000500  loss: 0.9972 (1.0227)  loss_classifier: 0.1794 (0.1860)  loss_box_reg: 0.4959 (0.4853)  loss_mask: 0.2838 (0.3037)  loss_objectness: 0.0137 (0.0143)  loss_rpn_box_reg: 0.0295 (0.0333)  time: 0.4168  data: 0.0147  max mem: 3301
# Epoch: [4]  [12/15]  eta: 0:00:01  lr: 0.000500  loss: 0.9972 (1.0198)  loss_classifier: 0.1814 (0.1865)  loss_box_reg: 0.4959 (0.4826)  loss_mask: 0.2946 (0.3039)  loss_objectness: 0.0137 (0.0141)  loss_rpn_box_reg: 0.0295 (0.0326)  time: 0.4185  data: 0.0141  max mem: 3301
# Epoch: [4]  [13/15]  eta: 0:00:00  lr: 0.000500  loss: 0.9850 (1.0051)  loss_classifier: 0.1794 (0.1826)  loss_box_reg: 0.4901 (0.4751)  loss_mask: 0.2838 (0.3010)  loss_objectness: 0.0119 (0.0137)  loss_rpn_box_reg: 0.0295 (0.0327)  time: 0.4179  data: 0.0135  max mem: 3301
# Epoch: [4]  [14/15]  eta: 0:00:00  lr: 0.000500  loss: 0.9972 (1.0074)  loss_classifier: 0.1794 (0.1824)  loss_box_reg: 0.4959 (0.4771)  loss_mask: 0.2838 (0.2996)  loss_objectness: 0.0137 (0.0153)  loss_rpn_box_reg: 0.0314 (0.0330)  time: 0.4173  data: 0.0130  max mem: 3301
# Epoch: [4] Total time: 0:00:06 (0.4207 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:02  model_time: 0.2172 (0.2172)  evaluator_time: 0.0892 (0.0892)  time: 0.4710  data: 0.1628  max mem: 3301
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1963 (0.1963)  evaluator_time: 0.0892 (0.0870)  time: 0.3272  data: 0.0383  max mem: 3301
# Test: Total time: 0:00:01 (0.3384 s / it)
# Averaged stats: model_time: 0.1963 (0.1963)  evaluator_time: 0.0892 (0.0870)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.535
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.138
# Epoch: [5]  [ 0/15]  eta: 0:00:10  lr: 0.000500  loss: 1.0796 (1.0796)  loss_classifier: 0.1945 (0.1945)  loss_box_reg: 0.5424 (0.5424)  loss_mask: 0.2788 (0.2788)  loss_objectness: 0.0162 (0.0162)  loss_rpn_box_reg: 0.0478 (0.0478)  time: 0.7011  data: 0.2548  max mem: 3301
# Epoch: [5]  [ 1/15]  eta: 0:00:07  lr: 0.000500  loss: 0.8343 (0.9569)  loss_classifier: 0.1519 (0.1732)  loss_box_reg: 0.3722 (0.4573)  loss_mask: 0.2706 (0.2747)  loss_objectness: 0.0073 (0.0117)  loss_rpn_box_reg: 0.0323 (0.0400)  time: 0.5593  data: 0.1317  max mem: 3301
# Epoch: [5]  [ 2/15]  eta: 0:00:06  lr: 0.000500  loss: 1.0638 (0.9926)  loss_classifier: 0.1594 (0.1686)  loss_box_reg: 0.5031 (0.4726)  loss_mask: 0.2788 (0.3048)  loss_objectness: 0.0077 (0.0104)  loss_rpn_box_reg: 0.0323 (0.0362)  time: 0.5120  data: 0.0901  max mem: 3301
# Epoch: [5]  [ 3/15]  eta: 0:00:05  lr: 0.000500  loss: 1.0207 (0.9996)  loss_classifier: 0.1519 (0.1633)  loss_box_reg: 0.5031 (0.4904)  loss_mask: 0.2782 (0.2982)  loss_objectness: 0.0077 (0.0109)  loss_rpn_box_reg: 0.0323 (0.0368)  time: 0.4863  data: 0.0694  max mem: 3301
# Epoch: [5]  [ 4/15]  eta: 0:00:05  lr: 0.000500  loss: 1.0207 (0.9971)  loss_classifier: 0.1594 (0.1708)  loss_box_reg: 0.5031 (0.4805)  loss_mask: 0.2788 (0.2969)  loss_objectness: 0.0125 (0.0114)  loss_rpn_box_reg: 0.0387 (0.0375)  time: 0.4724  data: 0.0570  max mem: 3301
# Epoch: [5]  [ 5/15]  eta: 0:00:04  lr: 0.000500  loss: 0.9870 (0.9754)  loss_classifier: 0.1519 (0.1674)  loss_box_reg: 0.4420 (0.4741)  loss_mask: 0.2782 (0.2896)  loss_objectness: 0.0077 (0.0106)  loss_rpn_box_reg: 0.0323 (0.0337)  time: 0.4619  data: 0.0486  max mem: 3301
# Epoch: [5]  [ 6/15]  eta: 0:00:04  lr: 0.000500  loss: 0.9870 (0.9668)  loss_classifier: 0.1551 (0.1656)  loss_box_reg: 0.4420 (0.4665)  loss_mask: 0.2788 (0.2920)  loss_objectness: 0.0078 (0.0102)  loss_rpn_box_reg: 0.0323 (0.0325)  time: 0.4551  data: 0.0428  max mem: 3301
# Epoch: [5]  [ 7/15]  eta: 0:00:03  lr: 0.000500  loss: 0.9870 (0.9815)  loss_classifier: 0.1551 (0.1764)  loss_box_reg: 0.4420 (0.4659)  loss_mask: 0.2788 (0.2969)  loss_objectness: 0.0077 (0.0096)  loss_rpn_box_reg: 0.0323 (0.0326)  time: 0.4539  data: 0.0383  max mem: 3301
# Epoch: [5]  [ 8/15]  eta: 0:00:03  lr: 0.000500  loss: 1.0207 (1.0048)  loss_classifier: 0.1594 (0.1849)  loss_box_reg: 0.4614 (0.4733)  loss_mask: 0.2917 (0.3028)  loss_objectness: 0.0078 (0.0106)  loss_rpn_box_reg: 0.0336 (0.0332)  time: 0.4527  data: 0.0348  max mem: 3301
# Epoch: [5]  [ 9/15]  eta: 0:00:02  lr: 0.000500  loss: 0.9966 (1.0040)  loss_classifier: 0.1594 (0.1825)  loss_box_reg: 0.4614 (0.4772)  loss_mask: 0.2877 (0.3013)  loss_objectness: 0.0077 (0.0099)  loss_rpn_box_reg: 0.0324 (0.0331)  time: 0.4488  data: 0.0320  max mem: 3301
# Epoch: [5]  [10/15]  eta: 0:00:02  lr: 0.000500  loss: 0.9966 (0.9971)  loss_classifier: 0.1604 (0.1816)  loss_box_reg: 0.4614 (0.4727)  loss_mask: 0.2903 (0.3003)  loss_objectness: 0.0078 (0.0101)  loss_rpn_box_reg: 0.0324 (0.0325)  time: 0.4459  data: 0.0303  max mem: 3301
# Epoch: [5]  [11/15]  eta: 0:00:01  lr: 0.000500  loss: 0.9870 (0.9865)  loss_classifier: 0.1604 (0.1810)  loss_box_reg: 0.4420 (0.4649)  loss_mask: 0.2877 (0.2984)  loss_objectness: 0.0078 (0.0104)  loss_rpn_box_reg: 0.0323 (0.0318)  time: 0.4438  data: 0.0284  max mem: 3301
# Epoch: [5]  [12/15]  eta: 0:00:01  lr: 0.000500  loss: 0.9966 (1.0039)  loss_classifier: 0.1729 (0.1850)  loss_box_reg: 0.4614 (0.4719)  loss_mask: 0.2903 (0.3030)  loss_objectness: 0.0121 (0.0112)  loss_rpn_box_reg: 0.0324 (0.0329)  time: 0.4415  data: 0.0267  max mem: 3301
# Epoch: [5]  [13/15]  eta: 0:00:00  lr: 0.000500  loss: 0.9870 (1.0020)  loss_classifier: 0.1729 (0.1843)  loss_box_reg: 0.4614 (0.4731)  loss_mask: 0.2877 (0.3007)  loss_objectness: 0.0121 (0.0113)  loss_rpn_box_reg: 0.0323 (0.0327)  time: 0.4395  data: 0.0252  max mem: 3301
# Epoch: [5]  [14/15]  eta: 0:00:00  lr: 0.000500  loss: 0.9870 (0.9957)  loss_classifier: 0.1741 (0.1836)  loss_box_reg: 0.4614 (0.4700)  loss_mask: 0.2877 (0.2985)  loss_objectness: 0.0121 (0.0111)  loss_rpn_box_reg: 0.0323 (0.0324)  time: 0.4362  data: 0.0239  max mem: 3301
# Epoch: [5] Total time: 0:00:06 (0.4397 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:01  model_time: 0.1945 (0.1945)  evaluator_time: 0.0519 (0.0519)  time: 0.3442  data: 0.0961  max mem: 3301
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1742 (0.1750)  evaluator_time: 0.0508 (0.0507)  time: 0.2515  data: 0.0230  max mem: 3301
# Test: Total time: 0:00:01 (0.2585 s / it)
# Averaged stats: model_time: 0.1742 (0.1750)  evaluator_time: 0.0508 (0.0507)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.506
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.560
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.520
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.135
# Epoch: [6]  [ 0/15]  eta: 0:00:07  lr: 0.000050  loss: 0.8582 (0.8582)  loss_classifier: 0.1350 (0.1350)  loss_box_reg: 0.4090 (0.4090)  loss_mask: 0.2887 (0.2887)  loss_objectness: 0.0062 (0.0062)  loss_rpn_box_reg: 0.0192 (0.0192)  time: 0.5132  data: 0.1031  max mem: 3301
# Epoch: [6]  [ 1/15]  eta: 0:00:06  lr: 0.000050  loss: 0.8582 (0.9567)  loss_classifier: 0.1350 (0.1853)  loss_box_reg: 0.4090 (0.4218)  loss_mask: 0.2887 (0.3139)  loss_objectness: 0.0062 (0.0098)  loss_rpn_box_reg: 0.0192 (0.0259)  time: 0.4812  data: 0.0553  max mem: 3301
# Epoch: [6]  [ 2/15]  eta: 0:00:05  lr: 0.000050  loss: 0.9533 (0.9556)  loss_classifier: 0.1400 (0.1702)  loss_box_reg: 0.4346 (0.4404)  loss_mask: 0.2887 (0.3018)  loss_objectness: 0.0134 (0.0143)  loss_rpn_box_reg: 0.0326 (0.0289)  time: 0.4613  data: 0.0393  max mem: 3301
# Epoch: [6]  [ 3/15]  eta: 0:00:05  lr: 0.000050  loss: 0.9533 (0.9584)  loss_classifier: 0.1400 (0.1664)  loss_box_reg: 0.4346 (0.4531)  loss_mask: 0.2878 (0.2983)  loss_objectness: 0.0062 (0.0122)  loss_rpn_box_reg: 0.0268 (0.0283)  time: 0.4503  data: 0.0311  max mem: 3301
# Epoch: [6]  [ 4/15]  eta: 0:00:04  lr: 0.000050  loss: 0.9533 (0.9533)  loss_classifier: 0.1481 (0.1627)  loss_box_reg: 0.4606 (0.4546)  loss_mask: 0.2878 (0.2909)  loss_objectness: 0.0134 (0.0132)  loss_rpn_box_reg: 0.0326 (0.0318)  time: 0.4436  data: 0.0262  max mem: 3301
# Epoch: [6]  [ 5/15]  eta: 0:00:04  lr: 0.000050  loss: 0.9330 (0.9477)  loss_classifier: 0.1481 (0.1645)  loss_box_reg: 0.4346 (0.4483)  loss_mask: 0.2878 (0.2919)  loss_objectness: 0.0077 (0.0123)  loss_rpn_box_reg: 0.0268 (0.0307)  time: 0.4392  data: 0.0230  max mem: 3301
# Epoch: [6]  [ 6/15]  eta: 0:00:03  lr: 0.000050  loss: 0.9330 (0.9262)  loss_classifier: 0.1481 (0.1585)  loss_box_reg: 0.4346 (0.4376)  loss_mask: 0.2878 (0.2881)  loss_objectness: 0.0090 (0.0118)  loss_rpn_box_reg: 0.0270 (0.0302)  time: 0.4369  data: 0.0209  max mem: 3301
# Epoch: [6]  [ 7/15]  eta: 0:00:03  lr: 0.000050  loss: 0.9330 (0.9584)  loss_classifier: 0.1481 (0.1684)  loss_box_reg: 0.4346 (0.4492)  loss_mask: 0.2878 (0.2964)  loss_objectness: 0.0090 (0.0124)  loss_rpn_box_reg: 0.0270 (0.0320)  time: 0.4358  data: 0.0211  max mem: 3301
# Epoch: [6]  [ 8/15]  eta: 0:00:03  lr: 0.000050  loss: 0.9533 (0.9629)  loss_classifier: 0.1549 (0.1678)  loss_box_reg: 0.4449 (0.4487)  loss_mask: 0.2887 (0.3034)  loss_objectness: 0.0090 (0.0116)  loss_rpn_box_reg: 0.0270 (0.0313)  time: 0.4342  data: 0.0195  max mem: 3301
# Epoch: [6]  [ 9/15]  eta: 0:00:02  lr: 0.000050  loss: 0.9330 (0.9571)  loss_classifier: 0.1549 (0.1667)  loss_box_reg: 0.4346 (0.4470)  loss_mask: 0.2878 (0.3002)  loss_objectness: 0.0090 (0.0122)  loss_rpn_box_reg: 0.0270 (0.0311)  time: 0.4334  data: 0.0186  max mem: 3301
# Epoch: [6]  [10/15]  eta: 0:00:02  lr: 0.000050  loss: 0.9330 (0.9457)  loss_classifier: 0.1549 (0.1645)  loss_box_reg: 0.4346 (0.4419)  loss_mask: 0.2878 (0.2956)  loss_objectness: 0.0134 (0.0141)  loss_rpn_box_reg: 0.0270 (0.0296)  time: 0.4322  data: 0.0176  max mem: 3301
# Epoch: [6]  [11/15]  eta: 0:00:01  lr: 0.000050  loss: 0.9330 (0.9458)  loss_classifier: 0.1548 (0.1637)  loss_box_reg: 0.4314 (0.4409)  loss_mask: 0.2878 (0.2973)  loss_objectness: 0.0134 (0.0142)  loss_rpn_box_reg: 0.0270 (0.0296)  time: 0.4318  data: 0.0167  max mem: 3301
# Epoch: [6]  [12/15]  eta: 0:00:01  lr: 0.000050  loss: 0.9463 (0.9545)  loss_classifier: 0.1549 (0.1664)  loss_box_reg: 0.4346 (0.4420)  loss_mask: 0.2887 (0.2997)  loss_objectness: 0.0163 (0.0155)  loss_rpn_box_reg: 0.0292 (0.0309)  time: 0.4314  data: 0.0161  max mem: 3301
# Epoch: [6]  [13/15]  eta: 0:00:00  lr: 0.000050  loss: 0.9330 (0.9508)  loss_classifier: 0.1549 (0.1661)  loss_box_reg: 0.4346 (0.4419)  loss_mask: 0.2878 (0.2970)  loss_objectness: 0.0151 (0.0155)  loss_rpn_box_reg: 0.0270 (0.0304)  time: 0.4292  data: 0.0154  max mem: 3301
# Epoch: [6]  [14/15]  eta: 0:00:00  lr: 0.000050  loss: 0.9330 (0.9488)  loss_classifier: 0.1566 (0.1666)  loss_box_reg: 0.4346 (0.4400)  loss_mask: 0.2887 (0.2973)  loss_objectness: 0.0151 (0.0148)  loss_rpn_box_reg: 0.0270 (0.0301)  time: 0.4311  data: 0.0148  max mem: 3301
# Epoch: [6] Total time: 0:00:06 (0.4357 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:01  model_time: 0.1927 (0.1927)  evaluator_time: 0.0523 (0.0523)  time: 0.3403  data: 0.0936  max mem: 3301
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1756 (0.1758)  evaluator_time: 0.0494 (0.0486)  time: 0.2499  data: 0.0227  max mem: 3301
# Test: Total time: 0:00:01 (0.2566 s / it)
# Averaged stats: model_time: 0.1756 (0.1758)  evaluator_time: 0.0494 (0.0486)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.421
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.437
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.545
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.496
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.135
# Epoch: [7]  [ 0/15]  eta: 0:00:07  lr: 0.000050  loss: 0.8640 (0.8640)  loss_classifier: 0.1604 (0.1604)  loss_box_reg: 0.4355 (0.4355)  loss_mask: 0.2490 (0.2490)  loss_objectness: 0.0045 (0.0045)  loss_rpn_box_reg: 0.0146 (0.0146)  time: 0.5144  data: 0.0999  max mem: 3301
# Epoch: [7]  [ 1/15]  eta: 0:00:06  lr: 0.000050  loss: 0.8577 (0.8608)  loss_classifier: 0.1351 (0.1478)  loss_box_reg: 0.4141 (0.4248)  loss_mask: 0.2490 (0.2624)  loss_objectness: 0.0045 (0.0052)  loss_rpn_box_reg: 0.0146 (0.0207)  time: 0.4680  data: 0.0539  max mem: 3301
# Epoch: [7]  [ 2/15]  eta: 0:00:05  lr: 0.000050  loss: 0.8577 (0.8416)  loss_classifier: 0.1351 (0.1425)  loss_box_reg: 0.4141 (0.4029)  loss_mask: 0.2758 (0.2694)  loss_objectness: 0.0059 (0.0066)  loss_rpn_box_reg: 0.0190 (0.0201)  time: 0.4556  data: 0.0385  max mem: 3301
# Epoch: [7]  [ 3/15]  eta: 0:00:05  lr: 0.000050  loss: 0.8577 (0.8671)  loss_classifier: 0.1351 (0.1485)  loss_box_reg: 0.4141 (0.4204)  loss_mask: 0.2654 (0.2684)  loss_objectness: 0.0059 (0.0073)  loss_rpn_box_reg: 0.0190 (0.0225)  time: 0.4456  data: 0.0305  max mem: 3301
# ...
# Epoch: [12] Total time: 0:00:06 (0.4292 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:02  model_time: 0.2159 (0.2159)  evaluator_time: 0.0837 (0.0837)  time: 0.4345  data: 0.1330  max mem: 3302
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1940 (0.1910)  evaluator_time: 0.0837 (0.0806)  time: 0.3099  data: 0.0340  max mem: 3302
# Test: Total time: 0:00:01 (0.3204 s / it)
# Averaged stats: model_time: 0.1940 (0.1910)  evaluator_time: 0.0837 (0.0806)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.427
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.452
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.525
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.150
# Epoch: [13]  [ 0/15]  eta: 0:00:08  lr: 0.000001  loss: 1.2166 (1.2166)  loss_classifier: 0.2331 (0.2331)  loss_box_reg: 0.5664 (0.5664)  loss_mask: 0.3525 (0.3525)  loss_objectness: 0.0205 (0.0205)  loss_rpn_box_reg: 0.0441 (0.0441)  time: 0.5442  data: 0.1377  max mem: 3302
# Epoch: [13]  [ 1/15]  eta: 0:00:06  lr: 0.000001  loss: 0.8555 (1.0361)  loss_classifier: 0.1441 (0.1886)  loss_box_reg: 0.3939 (0.4802)  loss_mask: 0.2852 (0.3189)  loss_objectness: 0.0078 (0.0142)  loss_rpn_box_reg: 0.0245 (0.0343)  time: 0.4786  data: 0.0727  max mem: 3302
# Epoch: [13]  [ 2/15]  eta: 0:00:05  lr: 0.000001  loss: 0.8652 (0.9791)  loss_classifier: 0.1514 (0.1762)  loss_box_reg: 0.3939 (0.4450)  loss_mask: 0.2918 (0.3098)  loss_objectness: 0.0090 (0.0125)  loss_rpn_box_reg: 0.0383 (0.0356)  time: 0.4607  data: 0.0507  max mem: 3302
# Epoch: [13]  [ 3/15]  eta: 0:00:05  lr: 0.000001  loss: 0.8555 (0.9386)  loss_classifier: 0.1498 (0.1696)  loss_box_reg: 0.3939 (0.4343)  loss_mask: 0.2852 (0.2940)  loss_objectness: 0.0078 (0.0104)  loss_rpn_box_reg: 0.0245 (0.0304)  time: 0.4474  data: 0.0397  max mem: 3302
# Epoch: [13]  [ 4/15]  eta: 0:00:04  lr: 0.000001  loss: 0.8652 (0.9284)  loss_classifier: 0.1514 (0.1681)  loss_box_reg: 0.4022 (0.4336)  loss_mask: 0.2852 (0.2865)  loss_objectness: 0.0090 (0.0101)  loss_rpn_box_reg: 0.0294 (0.0302)  time: 0.4409  data: 0.0332  max mem: 3302
# Epoch: [13]  [ 5/15]  eta: 0:00:04  lr: 0.000001  loss: 0.8652 (0.9433)  loss_classifier: 0.1514 (0.1735)  loss_box_reg: 0.4022 (0.4378)  loss_mask: 0.2852 (0.2876)  loss_objectness: 0.0090 (0.0117)  loss_rpn_box_reg: 0.0294 (0.0327)  time: 0.4355  data: 0.0288  max mem: 3302
# Epoch: [13]  [ 6/15]  eta: 0:00:03  lr: 0.000001  loss: 0.8877 (0.9691)  loss_classifier: 0.1621 (0.1805)  loss_box_reg: 0.4306 (0.4551)  loss_mask: 0.2852 (0.2867)  loss_objectness: 0.0090 (0.0125)  loss_rpn_box_reg: 0.0383 (0.0344)  time: 0.4320  data: 0.0257  max mem: 3302
# Epoch: [13]  [ 7/15]  eta: 0:00:03  lr: 0.000001  loss: 0.8652 (0.9494)  loss_classifier: 0.1514 (0.1729)  loss_box_reg: 0.4022 (0.4451)  loss_mask: 0.2814 (0.2853)  loss_objectness: 0.0090 (0.0125)  loss_rpn_box_reg: 0.0294 (0.0336)  time: 0.4308  data: 0.0233  max mem: 3302
# Epoch: [13]  [ 8/15]  eta: 0:00:03  lr: 0.000001  loss: 0.8877 (0.9522)  loss_classifier: 0.1514 (0.1690)  loss_box_reg: 0.4306 (0.4462)  loss_mask: 0.2852 (0.2925)  loss_objectness: 0.0090 (0.0118)  loss_rpn_box_reg: 0.0294 (0.0327)  time: 0.4289  data: 0.0215  max mem: 3302
# Epoch: [13]  [ 9/15]  eta: 0:00:02  lr: 0.000001  loss: 0.8877 (0.9477)  loss_classifier: 0.1498 (0.1670)  loss_box_reg: 0.4306 (0.4454)  loss_mask: 0.2814 (0.2911)  loss_objectness: 0.0090 (0.0118)  loss_rpn_box_reg: 0.0294 (0.0324)  time: 0.4277  data: 0.0200  max mem: 3302
# Epoch: [13]  [10/15]  eta: 0:00:02  lr: 0.000001  loss: 0.8892 (0.9424)  loss_classifier: 0.1514 (0.1663)  loss_box_reg: 0.4306 (0.4429)  loss_mask: 0.2814 (0.2896)  loss_objectness: 0.0091 (0.0115)  loss_rpn_box_reg: 0.0294 (0.0320)  time: 0.4245  data: 0.0190  max mem: 3302
# Epoch: [13]  [11/15]  eta: 0:00:01  lr: 0.000001  loss: 0.8892 (0.9391)  loss_classifier: 0.1514 (0.1664)  loss_box_reg: 0.4183 (0.4401)  loss_mask: 0.2814 (0.2902)  loss_objectness: 0.0090 (0.0110)  loss_rpn_box_reg: 0.0284 (0.0314)  time: 0.4234  data: 0.0180  max mem: 3302
# Epoch: [13]  [12/15]  eta: 0:00:01  lr: 0.000001  loss: 0.9028 (0.9426)  loss_classifier: 0.1592 (0.1687)  loss_box_reg: 0.4183 (0.4379)  loss_mask: 0.2852 (0.2931)  loss_objectness: 0.0091 (0.0116)  loss_rpn_box_reg: 0.0294 (0.0313)  time: 0.4249  data: 0.0171  max mem: 3302
# Epoch: [13]  [13/15]  eta: 0:00:00  lr: 0.000001  loss: 0.9028 (0.9433)  loss_classifier: 0.1592 (0.1705)  loss_box_reg: 0.4183 (0.4368)  loss_mask: 0.2852 (0.2939)  loss_objectness: 0.0090 (0.0112)  loss_rpn_box_reg: 0.0284 (0.0309)  time: 0.4263  data: 0.0163  max mem: 3302
# Epoch: [13]  [14/15]  eta: 0:00:00  lr: 0.000001  loss: 0.9028 (0.9398)  loss_classifier: 0.1621 (0.1700)  loss_box_reg: 0.4232 (0.4362)  loss_mask: 0.2852 (0.2921)  loss_objectness: 0.0090 (0.0109)  loss_rpn_box_reg: 0.0284 (0.0306)  time: 0.4253  data: 0.0156  max mem: 3302
# Epoch: [13] Total time: 0:00:06 (0.4286 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:01  model_time: 0.1939 (0.1939)  evaluator_time: 0.0561 (0.0561)  time: 0.3516  data: 0.0999  max mem: 3302
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1665 (0.1709)  evaluator_time: 0.0466 (0.0470)  time: 0.2436  data: 0.0236  max mem: 3302
# Test: Total time: 0:00:01 (0.2513 s / it)
# Averaged stats: model_time: 0.1665 (0.1709)  evaluator_time: 0.0466 (0.0470)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.414
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.024
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.142
# Epoch: [14]  [ 0/15]  eta: 0:00:07  lr: 0.000001  loss: 0.9523 (0.9523)  loss_classifier: 0.1734 (0.1734)  loss_box_reg: 0.4559 (0.4559)  loss_mask: 0.2847 (0.2847)  loss_objectness: 0.0114 (0.0114)  loss_rpn_box_reg: 0.0269 (0.0269)  time: 0.5258  data: 0.1153  max mem: 3302
# Epoch: [14]  [ 1/15]  eta: 0:00:06  lr: 0.000001  loss: 0.7897 (0.8710)  loss_classifier: 0.1320 (0.1527)  loss_box_reg: 0.3588 (0.4073)  loss_mask: 0.2772 (0.2809)  loss_objectness: 0.0033 (0.0073)  loss_rpn_box_reg: 0.0184 (0.0227)  time: 0.4673  data: 0.0612  max mem: 3302
# Epoch: [14]  [ 2/15]  eta: 0:00:05  lr: 0.000001  loss: 0.8476 (0.8632)  loss_classifier: 0.1500 (0.1518)  loss_box_reg: 0.3839 (0.3995)  loss_mask: 0.2801 (0.2807)  loss_objectness: 0.0083 (0.0077)  loss_rpn_box_reg: 0.0252 (0.0235)  time: 0.4533  data: 0.0431  max mem: 3302
# Epoch: [14]  [ 3/15]  eta: 0:00:05  lr: 0.000001  loss: 0.8476 (0.8645)  loss_classifier: 0.1500 (0.1570)  loss_box_reg: 0.3839 (0.4026)  loss_mask: 0.2772 (0.2740)  loss_objectness: 0.0074 (0.0076)  loss_rpn_box_reg: 0.0224 (0.0232)  time: 0.4372  data: 0.0339  max mem: 3302
# Epoch: [14]  [ 4/15]  eta: 0:00:04  lr: 0.000001  loss: 0.8683 (0.8690)  loss_classifier: 0.1698 (0.1595)  loss_box_reg: 0.3839 (0.3960)  loss_mask: 0.2801 (0.2783)  loss_objectness: 0.0083 (0.0114)  loss_rpn_box_reg: 0.0252 (0.0237)  time: 0.4397  data: 0.0285  max mem: 3302
# Epoch: [14]  [ 5/15]  eta: 0:00:04  lr: 0.000001  loss: 0.8683 (0.9241)  loss_classifier: 0.1698 (0.1750)  loss_box_reg: 0.3839 (0.4162)  loss_mask: 0.2801 (0.2927)  loss_objectness: 0.0074 (0.0107)  loss_rpn_box_reg: 0.0252 (0.0296)  time: 0.4423  data: 0.0274  max mem: 3302
# Epoch: [14]  [ 6/15]  eta: 0:00:03  lr: 0.000001  loss: 0.8683 (0.9054)  loss_classifier: 0.1698 (0.1681)  loss_box_reg: 0.3839 (0.4086)  loss_mask: 0.2801 (0.2890)  loss_objectness: 0.0083 (0.0104)  loss_rpn_box_reg: 0.0254 (0.0292)  time: 0.4400  data: 0.0267  max mem: 3302
# Epoch: [14]  [ 7/15]  eta: 0:00:03  lr: 0.000001  loss: 0.8683 (0.9050)  loss_classifier: 0.1500 (0.1658)  loss_box_reg: 0.3839 (0.4142)  loss_mask: 0.2772 (0.2858)  loss_objectness: 0.0074 (0.0100)  loss_rpn_box_reg: 0.0254 (0.0292)  time: 0.4383  data: 0.0257  max mem: 3302
# Epoch: [14]  [ 8/15]  eta: 0:00:03  lr: 0.000001  loss: 0.8870 (0.9266)  loss_classifier: 0.1698 (0.1683)  loss_box_reg: 0.4119 (0.4224)  loss_mask: 0.2801 (0.2953)  loss_objectness: 0.0083 (0.0114)  loss_rpn_box_reg: 0.0269 (0.0291)  time: 0.4392  data: 0.0248  max mem: 3302
# Epoch: [14]  [ 9/15]  eta: 0:00:02  lr: 0.000001  loss: 0.8870 (0.9321)  loss_classifier: 0.1500 (0.1663)  loss_box_reg: 0.4119 (0.4236)  loss_mask: 0.2801 (0.3015)  loss_objectness: 0.0083 (0.0119)  loss_rpn_box_reg: 0.0257 (0.0288)  time: 0.4369  data: 0.0236  max mem: 3302
# Epoch: [14]  [10/15]  eta: 0:00:02  lr: 0.000001  loss: 0.9020 (0.9509)  loss_classifier: 0.1698 (0.1710)  loss_box_reg: 0.4341 (0.4298)  loss_mask: 0.2847 (0.3052)  loss_objectness: 0.0090 (0.0146)  loss_rpn_box_reg: 0.0269 (0.0302)  time: 0.4368  data: 0.0237  max mem: 3302
# Epoch: [14]  [11/15]  eta: 0:00:01  lr: 0.000001  loss: 0.8870 (0.9427)  loss_classifier: 0.1650 (0.1705)  loss_box_reg: 0.4119 (0.4260)  loss_mask: 0.2801 (0.3023)  loss_objectness: 0.0090 (0.0141)  loss_rpn_box_reg: 0.0257 (0.0298)  time: 0.4352  data: 0.0223  max mem: 3302
# Epoch: [14]  [12/15]  eta: 0:00:01  lr: 0.000001  loss: 0.9020 (0.9506)  loss_classifier: 0.1698 (0.1725)  loss_box_reg: 0.4341 (0.4300)  loss_mask: 0.2847 (0.3011)  loss_objectness: 0.0094 (0.0165)  loss_rpn_box_reg: 0.0269 (0.0306)  time: 0.4339  data: 0.0211  max mem: 3302
# Epoch: [14]  [13/15]  eta: 0:00:00  lr: 0.000001  loss: 0.8870 (0.9449)  loss_classifier: 0.1657 (0.1720)  loss_box_reg: 0.4167 (0.4291)  loss_mask: 0.2801 (0.2978)  loss_objectness: 0.0094 (0.0166)  loss_rpn_box_reg: 0.0257 (0.0294)  time: 0.4324  data: 0.0200  max mem: 3302
# Epoch: [14]  [14/15]  eta: 0:00:00  lr: 0.000001  loss: 0.9020 (0.9538)  loss_classifier: 0.1698 (0.1737)  loss_box_reg: 0.4341 (0.4357)  loss_mask: 0.2847 (0.2973)  loss_objectness: 0.0094 (0.0160)  loss_rpn_box_reg: 0.0269 (0.0311)  time: 0.4311  data: 0.0191  max mem: 3302
# Epoch: [14] Total time: 0:00:06 (0.4354 s / it)
# creating index...
# index created!
# Test:  [0/5]  eta: 0:00:01  model_time: 0.1957 (0.1957)  evaluator_time: 0.0541 (0.0541)  time: 0.3480  data: 0.0965  max mem: 3302
# Test:  [4/5]  eta: 0:00:00  model_time: 0.1745 (0.1724)  evaluator_time: 0.0497 (0.0470)  time: 0.2446  data: 0.0229  max mem: 3302
# Test: Total time: 0:00:01 (0.2519 s / it)
# Averaged stats: model_time: 0.1745 (0.1724)  evaluator_time: 0.0497 (0.0470)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.897
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.260
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.418
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.331
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.169
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.194
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.150

# %%
model.eval()
model.roi_heads.score_thresh=0.5
model.roi_heads.nms_thresh=0.2

# %%
torch.save(model, '/content/sample_data/mask-rcnn.pth')
# model = torch.load('/content/mask-rcnn.pth')

# %%
# pick one image from the test set
img, _ = dataset_test[3]
to_tensor = T.ToTensor()
#img, _ = to_tensor(Image.open('/content/drive/MyDrive/333.jpg').convert("RGB"))
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

# %%
prediction[0]['masks'].shape
# Out:
# torch.Size([9, 1, 500, 500])

# %%
import torchvision.transforms as transforms
from torchvision.utils import draw_segmentation_masks, draw_bounding_boxes

to_pil_image = transforms.ToPILImage()
byte_img = img.mul(255).byte()

# %%
def mask_on_image(byte_img, prediction, th=0.7):
  masks = torch.squeeze(prediction[0]['masks']).cpu()
  threshold = torch.Tensor([th])
  masks = (masks > threshold).bool()
  masks_on_image = draw_segmentation_masks(
      image = byte_img,
      masks = masks,
      alpha=0.6
      )
  return to_pil_image(masks_on_image)

# %%
def box_on_image(byte_img, prediction):
  boxes = torch.squeeze(prediction[0]['boxes'])
  boxes_on_image = draw_bounding_boxes(
      image=byte_img,
      boxes=boxes,
      width=4
      )
  return to_pil_image(boxes_on_image)

# %%
to_pil_image(byte_img)

# %%
box_on_image(byte_img, prediction)

# %%
mask_on_image(byte_img, prediction, th=0.9)
mask_on_image(byte_img, prediction, th=0.8)
mask_on_image(byte_img, prediction, th=0.7)
mask_on_image(byte_img, prediction, th=0.6)
mask_on_image(byte_img, prediction, th=0.5)
mask_on_image(byte_img, prediction, th=0.4)
mask_on_image(byte_img, prediction, th=0.3)
mask_on_image(byte_img, prediction, th=0.2)
mask_on_image(byte_img, prediction, th=0.1)

# %%
mask_on_image(byte_img, prediction, th=0.5)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
# !rm -rf find -type d -name .ipynb_checkpoints
